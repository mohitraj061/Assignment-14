# %% [raw]
# Ques 1.) What does RGBA stand for ?
#
# Solution :
#
# RGBA stands for Red, Green, Blue, and Alpha. It is a color model used in computer graphics and digital imaging to represent
# colors and their transparency. Each component of the RGBA model represents the intensity of the respective color channel,
# ranging from 0 to 255, where 0 represents no intensity (black) and 255 represents full intensity (maximum brightness).
#
# The first three components, Red, Green, and Blue, represent the primary colors that are combined in different proportions to
# create a wide range of colors. The Alpha component represents the transparency or opacity of the color. A value of 0 means
# fully transparent, while a value of 255 means fully opaque. The RGBA model is commonly used in image editing software, web
# development, and other applications that involve color manipulation and transparency effects.

# %% [raw]
# Ques 2.) From the Pillow module, how do you get the RGBA value of any images ?
#
# Solution :
#
# In the Pillow module, we can obtain the RGBA (Red, Green, Blue, Alpha) values of an image by using the getpixel method.
# Here's an example :
#
# from PIL import Image
#
# # Open the image
# image = Image.open("example.jpg")
#
# # Get the RGBA value of a pixel at coordinates (x, y)
# x = 100
# y = 200
# rgba = image.getpixel((x, y))
#
# print(rgba)
#
# In the example above, the getpixel method is used to retrieve the RGBA value of a pixel at coordinates (x, y) in the image.
# The x and y variables represent the coordinates of the pixel we want to retrieve. The method returns a tuple containing the
# RGBA values of the pixel.
#
# Make sure to replace "example.jpg" with the path to our actual image file.

# %% [raw]
# Ques 3.) What is a box tuple, and how does it work ?
#
# Solution :
#
# In the context of the Pillow module in Python, a box tuple refers to a tuple that defines a rectangular region or bounding box.
# It is commonly used in various image manipulation operations to specify a specific area of an image.
#
# A box tuple typically consists of four values : (left, upper, right, lower). Here's a breakdown of each value :
#
# * left : The x-coordinate of the left edge of the bounding box.
# * upper : The y-coordinate of the upper edge of the bounding box.
# * right : The x-coordinate of the right edge of the bounding box.
# * lower : The y-coordinate of the lower edge of the bounding box.
#
# The coordinates are typically measured with the origin (0, 0) at the top-left corner of the image, where the x-axis increases
# from left to right, and the y-axis increases from top to bottom.
#
# When performing operations that involve a specific region of an image, such as cropping or extracting a sub-image, we can
# specify the box tuple to define the area of interest. The box tuple allows us to precisely define the rectangular region by
# specifying the coordinates of its four edges.
#
# For example, to crop an image using a box tuple, we can use the crop method from the Pillow module as follows :
#
# from PIL import Image
#
# # Open the image
# image = Image.open("example.jpg")
#
# # Define the box tuple (left, upper, right, lower)
# box = (100, 100, 300, 300)
#
# # Crop the image using the box tuple
# cropped_image = image.crop(box)
#
# # Display or save the cropped image as needed
# cropped_image.show()
#
# In the code snippet above, the crop method is used with the box tuple (100, 100, 300, 300) to extract a rectangular region
# from the image, which starts at (100, 100) and ends at (300, 300). The resulting cropped image is then displayed or saved as
# required.

# %% [raw]
# Ques 4.) Use your image and load in notebook then, How can you find out the width and height of an Image object ?
#
# Solution :
#
# To find out the width and height of an Image object using the Pillow module in Python, we can utilize the size attribute.
# Here's an example of loading an image and obtaining its dimensions :
#
# from PIL import Image
#
# # Open the image
# image = Image.open("example.jpg")
#
# # Get the width and height of the image
# width, height = image.size
#
# print("Width:", width)
# print("Height:", height)
#
# In the code snippet above, the size attribute of the Image object image is accessed to retrieve the width and height of the
# image. The size attribute returns a tuple containing the dimensions of the image, where the first element represents the width
# and the second element represents the height.
#
# By printing width and height, we can see the respective dimensions of the image in the output.

# %% [raw]
# Ques 5.) What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it ?
#
# Solution :
#
# To exclude the lower-left quarter of a 100x100 image and obtain an Image object with the remaining portion, we can use the
# crop method from the Pillow module. Here's an example :
#
# from PIL import Image
#
# # Open the image
# image = Image.open("example.jpg")
#
# # Define the coordinates of the box to exclude the lower-left quarter
# box = (0, 50, 50, 100)
#
# # Crop the image to exclude the lower-left quarter
# cropped_image = image.crop(box)
#
# # Display or save the cropped image as needed
# cropped_image.show()
#
# In the code snippet above, the crop method is used with the box tuple (0, 50, 50, 100) to exclude the lower-left quarter of the
# image. The box tuple specifies a region that starts from the top-left corner (0, 50) and ends at the bottom-right corner
# (50, 100) of the desired area to be cropped.
#
# The resulting cropped image will contain the portion of the image excluding the lower-left quarter. We can then display or
# save the cropped image as needed.

# %% [raw]
# Ques 6.) After making changes to an Image object, how could you save it as an image file ?
#
# Solution :
#
# To save changes made to an Image object as an image file using the Pillow module in Python, we can use the save method.
# Here's an example :
#
# from PIL import Image
#
# # Open the image
# image = Image.open("example.jpg")
#
# # Make changes to the image (e.g., crop, resize, apply filters, etc.)
#
# # Save the modified image to a file
# image.save("modified_example.jpg")
#
# In the code snippet above, after making changes to the image object, we can use the save method to save the modified image.
# The save method requires the path and filename of the file where we want to save the image.
#
# In the example, the modified image is saved as "modified_example.jpg". We can specify a different filename or file format
# (e.g., PNG, JPEG) depending on our requirements. Pillow automatically determines the file format based on the file extension
# provided.
#
# Once we call the save method, the modified image will be saved to the specified file path with the desired changes applied.

# %% [raw]
# Ques 7.) What module contains Pillow’s shape-drawing code ?
#
# Solution :
#
# Pillow's shape-drawing code is contained in the ImageDraw module. The ImageDraw module is part of the Pillow library in Python
# and provides functionality for drawing shapes, lines, and text on an Image object.
#
# To use the shape-drawing code in Pillow, we need to import the ImageDraw module. Here's an example :
#
# from PIL import Image, ImageDraw
#
# # Open an image
# image = Image.open("example.jpg")
#
# # Create an ImageDraw object
# draw = ImageDraw.Draw(image)
#
# # Use the ImageDraw object to draw shapes, lines, or text on the image
# draw.rectangle([(50, 50), (150, 150)], outline="red")
#
# # Save or display the modified image
# image.save("drawn_example.jpg")
#
# In the code snippet above, after opening an image and creating an ImageDraw object named draw, we can use the methods of the
# draw object to draw shapes, lines, or text on the image. In this example, the rectangle method is used to draw a red rectangle.
#
# We can then save or display the modified image as needed.

# %% [raw]
# Ques 8.) Image objects do not have drawing methods. What kind of object does ? How do you get this kind of object ?
#
# Solution :
#
# The Image object itself does not have drawing methods. Instead, the drawing methods are available in the ImageDraw module,
# which provides an object called ImageDraw.Draw that is capable of performing drawing operations on an image.
#
# To obtain the ImageDraw.Draw object, we can use the ImageDraw.Draw() method and pass in the Image object as an argument.
# Here's an example :
#
# from PIL import Image, ImageDraw
#
# # Open an image
# image = Image.open("example.jpg")
#
# # Create an ImageDraw.Draw object
# draw = ImageDraw.Draw(image)
#
# # Use the draw object to perform drawing operations on the image
# draw.rectangle([(50, 50), (150, 150)], outline="red")
#
# # Save or display the modified image
# image.save("drawn_example.jpg")
#
# In the code snippet above, after opening an image, the ImageDraw.Draw object is created by calling ImageDraw.Draw(image), where
# image is the Image object. The resulting draw object can then be used to perform drawing operations, such as drawing rectangles,
# lines, or text on the image.
#
# By utilizing the ImageDraw.Draw object, you can draw on the Image object and save or display the modified image with the
# desired changes applied.
